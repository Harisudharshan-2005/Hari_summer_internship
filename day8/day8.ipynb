# %%
# !pip install sentence-transformers chomadb groq -q
# Out:
# ERROR: Could not find a version that satisfies the requirement chomadb (from versions: none)
# ERROR: No matching distribution found for chomadb

# %%
# !pip install sentence-transformers chromadb groq pandas -q

# %%
import pandas as pd
import chromadb
from sentence
# Out:
#   File "/tmp/ipykernel_3851/1684826925.py", line 3
#     from sentence
#                  ^
# SyntaxError: invalid syntax

# %%
# !pip install sentence-transformers chromadb groq pandas
import pandas as pd

import chromadb

from sentence_transformers import SentenceTransformer

from groq import Groq

import os

print("All libraries imported")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# Set your Groq API key here
# You can obtain a key from https://console.groq.com/keys
os.environ["GROQ_API_KEY"] = "#########################"

print("GROQ_API_KEY has been set (remember to replace 'YOUR_GROQ_API_KEY' with your actual key).")
# Out:
# GROQ_API_KEY has been set (remember to replace 'YOUR_GROQ_API_KEY' with your actual key).

# %%
import os

# This will print the value of the GROQ_API_KEY environment variable
# If it prints 'YOUR_GROQ_API_KEY', you need to update cell '5f9158c8' with your actual key.
print(f"Current GROQ_API_KEY: {os.environ.get('')}")
# Out:
# Current GROQ_API_KEY: None

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import chromadb

# --- Step 1: Define or Load Data ---
# If 'df' isn't already defined, we create a sample one for the RAG system
try:
    df
except NameError:
    data = {
        'note_id': [1, 2, 3],
        'subject': ['Data Engineering', 'Python Programming', 'Data Engineering'],
        'topic': ['ETL Pipelines', 'Data Visualization', 'SQL Databases'],
        'content': [
            'ETL stands for Extract Transform Load. It is the process of collecting raw data from different sources transforming it into a usable format and loading it into a final destination.',
            'Data visualization is the process of representing data as charts graphs and visual formats. Python libraries like Matplotlib and Seaborn are common.',
            'A database is an organized collection of data stored electronically. SQL or Structured Query Language is used to interact with relational databases.'
        ]
    }
    df = pd.DataFrame(data)
    print("Sample DataFrame 'df' created.")

# Initialize the embedding model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# Initialize ChromaDB client
client = chromadb.PersistentClient(path='./chroma_db')
collection_name = "rag_notes_collection"
collection = client.get_or_create_collection(name=collection_name)

# Prepare documents, metadatas, and IDs from the DataFrame
documents = df['content'].fillna('').tolist()
metadatas = df[['subject', 'topic']].fillna('Unknown').to_dict(orient='records')
ids = [f"note_{nid}" for nid in df['note_id'].fillna('nan')]

# Add documents to the collection if it's empty
if collection.count() == 0:
    collection.add(
        documents=documents,
        metadatas=metadatas,
        ids=ids
    )
    print(f"Added {collection.count()} documents to the collection '{collection_name}'.")
else:
    print(f"Collection '{collection_name}' already contains {collection.count()} documents.")

print("ChromaDB collection and embedding model initialized.")
# Out:
# Sample DataFrame 'df' created.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:00<00:00, 104MiB/s]
# Added 3 documents to the collection 'rag_notes_collection'.
# ChromaDB collection and embedding model initialized.

# %%
print("Subjects in the dataset:")

# Get counts of how many times each unique value appears in the 'subject' column
print(df['subject'].value_counts())

print("Sample of topics:")

# Display the 'note_id', 'subject', and 'topic' columns to understand available knowledge
print(df[['note_id', 'subject', 'topic']].to_string(index=False))

# .to_string(index=False): Converts to string and hides row numbers

print("\nLength of content (number of characters) for each note:")

# Calculate the length of content for each note and store it in a new 'content_length' column
df['content_length'] = df['content'].fillna('').apply(len) # Fills NaN with empty string before applying len()

print(df[['topic', 'content_length']].to_string(index=False))
# Out:
# Subjects in the dataset:
# subject
# Data Engineering      2
# Python Programming    1
# Name: count, dtype: int64
# Sample of topics:
#  note_id            subject              topic
#        1   Data Engineering      ETL Pipelines
#        2 Python Programming Data Visualization
#        3   Data Engineering      SQL Databases
#
# Length of content (number of characters) for each note:
#              topic  content_length
#      ETL Pipelines             180
# Data Visualization             148
#      SQL Databases             148

# %%
def retrieve_relevant_chunks(question, top_k=3):

    question_embedding = embedding_model.encode(question).tolist()


    results = collection.query(
        query_embeddings=[question_embedding],
        n_results=top_k,
        include=['documents', 'distances', 'metadatas']
    )

    return results

    print("retrieval function defined successfuly")
    print("function: retrieval_relevant_chuks(question, top_k = 3) ")

# %%
def retrieve_relevant_chunks(question, top_k=3):

    question_embedding = embedding_model.encode(question).tolist()


    results = collection.query(
        query_embeddings=[question_embedding],
        n_results=top_k,
        include=['documents', 'distances', 'metadatas']
    )

    return results

    print("retrieval function defined successfuly")
    print("function: retrieval_relevant_chuks(question, top_k = 3) ")

# %%
# We use zip() to pair each document with its distance and metadata

# Test Question:
question = "What is ETL and how does it work in data engineering?"

# Retrieve relevant chunks based on the question
results = retrieve_relevant_chunks(question)

for i, (doc, dist, neta) in enumerate(zip(
    results['documents'][0],
    results['distances'][0],
    results['metadatas'][0]
)):
    print(f"\nResult ({i+1}):")
    print(f"Subject: {neta['subject']}")
    print(f"Topic: {neta['topic']}")
    print(f"Distance: {dist:.4f}")
    # Distance: lower value means more similar to our question
    # ChromaDB uses L2 distance by default (Euclidean distance)
    print(f"Content: {doc[:120]}...")
    # We show only the first 120 characters to keep output readable
# Out:
# Result (1):
# Subject: Data Engineering
# Topic: ETL Pipelines
# Distance: 0.2441
# Content: ETL stands for Extract Transform Load. It is the process of collecting raw data from different sources transforming it i...
#
# Result (2):
# Subject: Python Programming
# Topic: Data Visualization
# Distance: 1.3125
# Content: Data visualization is the process of representing data as charts graphs and visual formats. Python libraries like Matplo...
#
# Result (3):
# Subject: Data Engineering
# Topic: SQL Databases
# Distance: 1.3134
# Content: A database is an organized collection of data stored electronically. SQL or Structured Query Language is used to interac...

# %%
def generate_rag_answer(question, context):
    """
    This function sends the context question to Groq LLM and returns the answer.

    Sends the retrieved context and question to Groq LLM.

    Parameters:
    question (str): The user's query, e.g., '[Source 1: Data Engineering ETL Pipeli....'
    context (str): The retrieved context chunks (formatted string).

    Returns:
    str: The LLM's generated answer.

    SYSTEM PROMPT: Instructions to the LLM about its role and behavior.
    # This is the key to RAG, we tell the LLM to ONLY use the provided context.
    """
    # Placeholder for Groq LLM interaction
    system_prompt = "You are a helpful academic assistant for engineering students."
    # Actual implementation for sending to Groq LLM would go here
    # For demonstration, returning a formatted string.
    return f"Generated answer for question: '{question}' using context: '{context}'"

# %%
def generate_rag_answer(question, context):
    system_prompt = "You are a helpful academic assistant for engineering students. Only use the provided context to answer the question. If the answer is not in the context, politely say that you don't have enough information."
    client = Groq(
        api_key=os.environ.get("GROQ_API_KEY"),
    )
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": system_prompt,
            },
            {
                "role": "user",
                "content": f"Context: {context}\n\nQuestion: {question}",
            },
        ],
        model="llama-3.1-8b-instant",
        temperature=0.0,
    )
    return chat_completion.choices[0].message.content

# %%
print('--- Testing the RAG Answer Generation ---')

# Format the retrieved context for the LLM
context_for_llm = "\n\n".join(results['documents'][0])

# Generate the RAG answer using the updated function (now using llama-3.1-8b-instant)
rag_answer = generate_rag_answer(question, context_for_llm)

print(f"\nQuestion: {question}")
print(f"\nRetrieved Context (first 200 chars): {context_for_llm[:200]}...")
print(f"\nGenerated Answer:\n{rag_answer}")
# Out:
# --- Testing the RAG Answer Generation ---
#
# Question: What is ETL and how does it work in data engineering?
#
# Retrieved Context (first 200 chars): ETL stands for Extract Transform Load. It is the process of collecting raw data from different sources transforming it into a usable format and loading it into a final destination.
#
# Data visualization...
#
# Generated Answer:
# ETL stands for Extract, Transform, and Load. It's a crucial process in data engineering that involves collecting raw data from various sources, transforming it into a usable format, and loading it into a final destination.
#
# Here's a step-by-step breakdown of how ETL works in data engineering:
#
# 1. **Extract**: In this phase, raw data is collected from different sources, such as databases, files, or APIs. This data may be in various formats, including CSV, JSON, or XML.
# ...
